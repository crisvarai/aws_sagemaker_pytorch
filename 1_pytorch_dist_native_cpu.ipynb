# %% [markdown]
# # ***PyTorch Native Distributed Training with Amazon SageMaker***

# %%
# !pip install sagemaker --upgrade -q
# !pip install ipywidgets -q

# %% [markdown]
# **Step 1:** Import essentials packages, start a sagemaker session and specify the bucket name you created in the pre-requsites section of this workshop.

# %%
import os
import boto3
import time
import numpy as np
import sagemaker

sess = boto3.Session()
sm   = sess.client('sagemaker')
sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()

bucket_name    = sagemaker_session.default_bucket()
jobs_folder    = 'jobs'
dataset_folder = 'datasets'

# %% [markdown]
# ![](https://miro.medium.com/max/1000/0*GRfvsrvtfpRm400-)

# %% [markdown]
# #### Prepare the training data
# The CIFAR-10 dataset is a subset of the 80 million tiny images dataset. It consists of 60,000 32x32 color images in 10 classes, with 6,000 images per class.

# %%
import torchvision
cifar10_dataset = torchvision.datasets.CIFAR10('cifar10-dataset', 
                                     train=True, 
                                     download=True)

datasets = sagemaker_session.upload_data(path='cifar10-dataset', 
                                         key_prefix=f'{dataset_folder}/cifar10-dataset')

datasets
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to cifar10-dataset/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting cifar10-dataset/cifar-10-python.tar.gz to cifar10-dataset
# 's3://sagemaker-us-east-1-985160386910/datasets/cifar10-dataset'

# %% [markdown]
# **Step 2:** Specify hyperparameters, instance type and number of instances to distribute training to.

# %%
job_name   = f'pytorch-native-dist-{time.strftime("%Y-%m-%d-%H-%M-%S-%j", time.gmtime())}'
output_path = f's3://{bucket_name}/{jobs_folder}'

hyperparameters = {'epochs'       : 20, 
                   'lr'           : 0.01,
                   'momentum'     : 0.9,
                   'batch-size'   : 64,
                   'model-type'   : 'custom',
                   'backend'      : 'gloo'}

# %%
from sagemaker.pytorch import PyTorch
estimator = PyTorch(entry_point         = 'cifar10-distributed-native-cpu.py', 
                           source_dir           = 'code',
                           output_path          = output_path + '/',
                           code_location        = output_path,
                           role                 = role,
                           instance_count       = 2,
                           instance_type        = 'ml.c5.2xlarge',
                           framework_version    = '1.8.0', 
                           py_version           = 'py3',
                           hyperparameters      = hyperparameters)

# %% [markdown]
# **Step 4:** Specify dataset locations in Amazon S3 and then call the fit function.

# %%
estimator.fit({'train': datasets}, 
              job_name=job_name, 
              wait=True)
# Out:
# 2023-05-15 20:35:34 Starting - Starting the training job...
# 2023-05-15 20:35:58 Starting - Preparing the instances for trainingProfilerReport-1684182934: InProgress
# ......
# 2023-05-15 20:36:58 Downloading - Downloading input data...
# 2023-05-15 20:37:32 Training - Training image download completed. Training in progress...bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2023-05-15 20:37:42,904 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2023-05-15 20:37:42,906 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2023-05-15 20:37:42,915 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2023-05-15 20:37:42,917 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2023-05-15 20:37:43,037 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2023-05-15 20:37:43,049 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2023-05-15 20:37:43,060 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2023-05-15 20:37:43,069 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-2",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "backend": "gloo",
#         "batch-size": 64,
#         "epochs": 20,
#         "lr": 0.01,
#         "model-type": "custom",
#         "momentum": 0.9
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": false,
#     "job_name": "pytorch-native-dist-2023-05-15-20-35-24-135",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-985160386910/jobs/pytorch-native-dist-2023-05-15-20-35-24-135/source/sourcedir.tar.gz",
#     "module_name": "cifar10-distributed-native-cpu",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-2",
#         "current_instance_type": "ml.c5.2xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.c5.2xlarge",
#                 "hosts": [
#                     "algo-1",
#                     "algo-2"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "cifar10-distributed-native-cpu.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"backend":"gloo","batch-size":64,"epochs":20,"lr":0.01,"model-type":"custom","momentum":0.9}
# SM_USER_ENTRY_POINT=cifar10-distributed-native-cpu.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-2","current_instance_type":"ml.c5.2xlarge","hosts":["algo-1","algo-2"],"instance_groups":[{"hosts":["algo-1","algo-2"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c5.2xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-2
# SM_MODULE_NAME=cifar10-distributed-native-cpu
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-985160386910/jobs/pytorch-native-dist-2023-05-15-20-35-24-135/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-2","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"backend":"gloo","batch-size":64,"epochs":20,"lr":0.01,"model-type":"custom","momentum":0.9},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":false,"job_name":"pytorch-native-dist-2023-05-15-20-35-24-135","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-985160386910/jobs/pytorch-native-dist-2023-05-15-20-35-24-135/source/sourcedir.tar.gz","module_name":"cifar10-distributed-native-cpu","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-2","current_instance_type":"ml.c5.2xlarge","hosts":["algo-1","algo-2"],"instance_groups":[{"hosts":["algo-1","algo-2"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c5.2xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"cifar10-distributed-native-cpu.py"}
# SM_USER_ARGS=["--backend","gloo","--batch-size","64","--epochs","20","--lr","0.01","--model-type","custom","--momentum","0.9"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_BACKEND=gloo
# SM_HP_BATCH-SIZE=64
# SM_HP_EPOCHS=20
# SM_HP_LR=0.01
# SM_HP_MODEL-TYPE=custom
# SM_HP_MOMENTUM=0.9
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.6 cifar10-distributed-native-cpu.py --backend gloo --batch-size 64 --epochs 20 --lr 0.01 --model-type custom --momentum 0.9
# Distributed training - True
# bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2023-05-15 20:37:42,938 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2023-05-15 20:37:42,941 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2023-05-15 20:37:42,950 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2023-05-15 20:37:42,952 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2023-05-15 20:37:43,073 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2023-05-15 20:37:43,085 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2023-05-15 20:37:43,096 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2023-05-15 20:37:43,106 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "backend": "gloo",
#         "batch-size": 64,
#         "epochs": 20,
#         "lr": 0.01,
#         "model-type": "custom",
#         "momentum": 0.9
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "pytorch-native-dist-2023-05-15-20-35-24-135",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-985160386910/jobs/pytorch-native-dist-2023-05-15-20-35-24-135/source/sourcedir.tar.gz",
#     "module_name": "cifar10-distributed-native-cpu",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.c5.2xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.c5.2xlarge",
#                 "hosts": [
#                     "algo-1",
#                     "algo-2"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "cifar10-distributed-native-cpu.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"backend":"gloo","batch-size":64,"epochs":20,"lr":0.01,"model-type":"custom","momentum":0.9}
# SM_USER_ENTRY_POINT=cifar10-distributed-native-cpu.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.c5.2xlarge","hosts":["algo-1","algo-2"],"instance_groups":[{"hosts":["algo-1","algo-2"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c5.2xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=cifar10-distributed-native-cpu
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-985160386910/jobs/pytorch-native-dist-2023-05-15-20-35-24-135/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"backend":"gloo","batch-size":64,"epochs":20,"lr":0.01,"model-type":"custom","momentum":0.9},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"pytorch-native-dist-2023-05-15-20-35-24-135","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-985160386910/jobs/pytorch-native-dist-2023-05-15-20-35-24-135/source/sourcedir.tar.gz","module_name":"cifar10-distributed-native-cpu","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.c5.2xlarge","hosts":["algo-1","algo-2"],"instance_groups":[{"hosts":["algo-1","algo-2"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c5.2xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"cifar10-distributed-native-cpu.py"}
# SM_USER_ARGS=["--backend","gloo","--batch-size","64","--epochs","20","--lr","0.01","--model-type","custom","--momentum","0.9"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_BACKEND=gloo
# SM_HP_BATCH-SIZE=64
# SM_HP_EPOCHS=20
# SM_HP_LR=0.01
# SM_HP_MODEL-TYPE=custom
# SM_HP_MOMENTUM=0.9
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.6 cifar10-distributed-native-cpu.py --backend gloo --batch-size 64 --epochs 20 --lr 0.01 --model-type custom --momentum 0.9
# Distributed training - True
# Initialized the distributed environment: 'gloo' backend on 2 nodes.
# Get train data loader
# Initialized the distributed environment: 'gloo' backend on 2 nodes.
# Get train data loader
# Get test data loader
# Get test data loader
# Processes 25000/50000 (50%) of train data
# Processes 10000/10000 (100%) of test data
# [2023-05-15 20:37:45.552 algo-2:27 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-05-15 20:37:45.718 algo-2:27 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2023-05-15 20:37:45.719 algo-2:27 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-05-15 20:37:45.719 algo-2:27 INFO hook.py:199] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-05-15 20:37:45.719 algo-2:27 INFO hook.py:253] Saving to /opt/ml/output/tensors
# [2023-05-15 20:37:45.719 algo-2:27 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-05-15 20:37:45.743 algo-2:27 INFO hook.py:584] name:module.conv1.weight count_params:450
# [2023-05-15 20:37:45.743 algo-2:27 INFO hook.py:584] name:module.conv1.bias count_params:6
# [2023-05-15 20:37:45.743 algo-2:27 INFO hook.py:584] name:module.conv2.weight count_params:2400
# [2023-05-15 20:37:45.743 algo-2:27 INFO hook.py:584] name:module.conv2.bias count_params:16
# [2023-05-15 20:37:45.743 algo-2:27 INFO hook.py:584] name:module.fc1.weight count_params:48000
# [2023-05-15 20:37:45.743 algo-2:27 INFO hook.py:584] name:module.fc1.bias count_params:120
# [2023-05-15 20:37:45.743 algo-2:27 INFO hook.py:584] name:module.fc2.weight count_params:10080
# [2023-05-15 20:37:45.743 algo-2:27 INFO hook.py:584] name:module.fc2.bias count_params:84
# [2023-05-15 20:37:45.743 algo-2:27 INFO hook.py:584] name:module.fc3.weight count_params:840
# [2023-05-15 20:37:45.743 algo-2:27 INFO hook.py:584] name:module.fc3.bias count_params:10
# [2023-05-15 20:37:45.743 algo-2:27 INFO hook.py:586] Total Trainable Params: 62006
# [2023-05-15 20:37:45.743 algo-2:27 INFO hook.py:413] Monitoring the collections: losses
# Processes 25000/50000 (50%) of train data
# Processes 10000/10000 (100%) of test data
# [2023-05-15 20:37:45.556 algo-1:27 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-05-15 20:37:45.727 algo-1:27 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2023-05-15 20:37:45.727 algo-1:27 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-05-15 20:37:45.727 algo-1:27 INFO hook.py:199] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-05-15 20:37:45.728 algo-1:27 INFO hook.py:253] Saving to /opt/ml/output/tensors
# [2023-05-15 20:37:45.728 algo-1:27 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-05-15 20:37:45.748 algo-1:27 INFO hook.py:584] name:module.conv1.weight count_params:450
# [2023-05-15 20:37:45.748 algo-1:27 INFO hook.py:584] name:module.conv1.bias count_params:6
# [2023-05-15 20:37:45.748 algo-1:27 INFO hook.py:584] name:module.conv2.weight count_params:2400
# [2023-05-15 20:37:45.749 algo-1:27 INFO hook.py:584] name:module.conv2.bias count_params:16
# [2023-05-15 20:37:45.749 algo-1:27 INFO hook.py:584] name:module.fc1.weight count_params:48000
# [2023-05-15 20:37:45.749 algo-1:27 INFO hook.py:584] name:module.fc1.bias count_params:120
# [2023-05-15 20:37:45.749 algo-1:27 INFO hook.py:584] name:module.fc2.weight count_params:10080
# [2023-05-15 20:37:45.749 algo-1:27 INFO hook.py:584] name:module.fc2.bias count_params:84
# [2023-05-15 20:37:45.749 algo-1:27 INFO hook.py:584] name:module.fc3.weight count_params:840
# [2023-05-15 20:37:45.749 algo-1:27 INFO hook.py:584] name:module.fc3.bias count_params:10
# [2023-05-15 20:37:45.749 algo-1:27 INFO hook.py:586] Total Trainable Params: 62006
# [2023-05-15 20:37:45.749 algo-1:27 INFO hook.py:413] Monitoring the collections: losses
# Train Epoch: 1 [6400/25000 (26%)] Loss: 2.117595
# Train Epoch: 1 [6400/25000 (26%)] Loss: 2.078174
# Train Epoch: 1 [12800/25000 (51%)] Loss: 2.035070
# Train Epoch: 1 [12800/25000 (51%)] Loss: 1.822954
# Train Epoch: 1 [19200/25000 (77%)] Loss: 1.777211
# Train Epoch: 1 [19200/25000 (77%)] Loss: 1.874125
# Test set: Average loss: -1.2011, Accuracy: 0.39
# Train Epoch: 2 [6400/25000 (26%)] Loss: 1.449694
# Test set: Average loss: -1.2011, Accuracy: 0.39
# Train Epoch: 2 [6400/25000 (26%)] Loss: 1.388150
# Train Epoch: 2 [12800/25000 (51%)] Loss: 1.391975
# Train Epoch: 2 [12800/25000 (51%)] Loss: 1.626726
# Train Epoch: 2 [19200/25000 (77%)] Loss: 1.564608
# Train Epoch: 2 [19200/25000 (77%)] Loss: 1.725243
# Test set: Average loss: -1.5805, Accuracy: 0.47
# Test set: Average loss: -1.5805, Accuracy: 0.47
# Train Epoch: 3 [6400/25000 (26%)] Loss: 1.339296
# Train Epoch: 3 [6400/25000 (26%)] Loss: 1.152442
# Train Epoch: 3 [12800/25000 (51%)] Loss: 1.269444
# Train Epoch: 3 [12800/25000 (51%)] Loss: 1.511233
# Train Epoch: 3 [19200/25000 (77%)] Loss: 1.328532
# Train Epoch: 3 [19200/25000 (77%)] Loss: 1.438142
# Test set: Average loss: -1.9070, Accuracy: 0.49
# Test set: Average loss: -1.9070, Accuracy: 0.49
# Train Epoch: 4 [6400/25000 (26%)] Loss: 1.152379
# Train Epoch: 4 [6400/25000 (26%)] Loss: 1.357175
# Train Epoch: 4 [12800/25000 (51%)] Loss: 1.386630
# Train Epoch: 16 [12800/25000 (51%)] Loss: 0.934828
# Train Epoch: 16 [12800/25000 (51%)] Loss: 1.010774
# Train Epoch: 16 [19200/25000 (77%)] Loss: 0.962103
# Train Epoch: 16 [19200/25000 (77%)] Loss: 1.008241
# Test set: Average loss: -3.3034, Accuracy: 0.61
# Test set: Average loss: -3.3034, Accuracy: 0.61
# Train Epoch: 17 [6400/25000 (26%)] Loss: 1.017287
# Train Epoch: 17 [6400/25000 (26%)] Loss: 0.700664
# Train Epoch: 17 [12800/25000 (51%)] Loss: 1.196817
# Train Epoch: 17 [12800/25000 (51%)] Loss: 0.829805
# Train Epoch: 17 [19200/25000 (77%)] Loss: 1.056797
# Train Epoch: 17 [19200/25000 (77%)] Loss: 0.808202
# Test set: Average loss: -3.4700, Accuracy: 0.62
# Train Epoch: 18 [6400/25000 (26%)] Loss: 0.747723
# Train Epoch: 18 [12800/25000 (51%)] Loss: 1.101501
# Train Epoch: 18 [19200/25000 (77%)] Loss: 1.038602
# Test set: Average loss: -3.4769, Accuracy: 0.62
# Train Epoch: 19 [6400/25000 (26%)] Loss: 0.699385
# Train Epoch: 19 [12800/25000 (51%)] Loss: 1.199876
# Train Epoch: 19 [19200/25000 (77%)] Loss: 1.124347
# Test set: Average loss: -3.4700, Accuracy: 0.62
# Train Epoch: 18 [6400/25000 (26%)] Loss: 0.793171
# Train Epoch: 18 [12800/25000 (51%)] Loss: 0.894658
# Train Epoch: 18 [19200/25000 (77%)] Loss: 0.746973
# Test set: Average loss: -3.4769, Accuracy: 0.62
# Train Epoch: 19 [6400/25000 (26%)] Loss: 0.877008
# Train Epoch: 19 [12800/25000 (51%)] Loss: 0.929345
# Train Epoch: 19 [19200/25000 (77%)] Loss: 0.880854
# Test set: Average loss: -3.5882, Accuracy: 0.62
# Test set: Average loss: -3.5882, Accuracy: 0.62
# Train Epoch: 20 [6400/25000 (26%)] Loss: 0.742572
# Train Epoch: 20 [6400/25000 (26%)] Loss: 0.741379
# Train Epoch: 20 [12800/25000 (51%)] Loss: 0.989639
# Train Epoch: 20 [12800/25000 (51%)] Loss: 0.906624
# Train Epoch: 20 [19200/25000 (77%)] Loss: 1.056612
# Train Epoch: 20 [19200/25000 (77%)] Loss: 0.738991
# Test set: Average loss: -3.6844, Accuracy: 0.61
# Saving trained model only on rank 0
# Test set: Average loss: -3.6844, Accuracy: 0.61
# Saving trained model only on rank 0
# Saving the model.
# INFO:__main__:Initialized the distributed environment: 'gloo' backend on 2 nodes.
# INFO:__main__:Get train data loader
# INFO:__main__:Get test data loader
# DEBUG:__main__:Processes 25000/50000 (50%) of train data
# DEBUG:__main__:Processes 10000/10000 (100%) of test data
# /opt/conda/lib/python3.6/site-packages/torch/distributed/distributed_c10d.py:144: UserWarning: torch.distributed.reduce_op is deprecated, please use torch.distributed.ReduceOp instead
#   warnings.warn("torch.distributed.reduce_op is deprecated, please use "
# INFO:__main__:Train Epoch: 1 [6400/25000 (26%)] Loss: 2.078174
# INFO:__main__:Train Epoch: 1 [12800/25000 (51%)] Loss: 2.035070
# INFO:__main__:Train Epoch: 1 [19200/25000 (77%)] Loss: 1.777211
# /opt/conda/lib/python3.6/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# INFO:__main__:Train Epoch: 17 [6400/25000 (26%)] Loss: 1.017287
# INFO:__main__:Train Epoch: 17 [12800/25000 (51%)] Loss: 0.829805
# INFO:__main__:Train Epoch: 17 [19200/25000 (77%)] Loss: 0.808202
# INFO:__main__:Test set: Average loss: -3.4700, Accuracy: 0.62
# INFO:__main__:Train Epoch: 18 [6400/25000 (26%)] Loss: 0.793171
# INFO:__main__:Train Epoch: 18 [12800/25000 (51%)] Loss: 0.894658
# INFO:__main__:Train Epoch: 18 [19200/25000 (77%)] Loss: 0.746973
# INFO:__main__:Test set: Average loss: -3.4769, Accuracy: 0.62
# INFO:__main__:Train Epoch: 19 [6400/25000 (26%)] Loss: 0.877008
# INFO:__main__:Train Epoch: 19 [12800/25000 (51%)] Loss: 0.929345
# INFO:__main__:Train Epoch: 19 [19200/25000 (77%)] Loss: 0.880854
# INFO:__main__:Test set: Average loss: -3.5882, Accuracy: 0.62
# INFO:__main__:Train Epoch: 20 [6400/25000 (26%)] Loss: 0.742572
# INFO:__main__:Train Epoch: 20 [12800/25000 (51%)] Loss: 0.906624
# INFO:__main__:Train Epoch: 20 [19200/25000 (77%)] Loss: 0.738991
# INFO:__main__:Test set: Average loss: -3.6844, Accuracy: 0.61
# INFO:__main__:Saving trained model only on rank 0
#
# 2023-05-15 20:43:19 Uploading - Uploading generated training model
# 2023-05-15 20:43:19 Completed - Training job completed
# ProfilerReport-1684182934: NoIssuesFound
# Training seconds: 754
# Billable seconds: 754

# %%
estimator.model_data
# Out:
# 's3://sagemaker-us-east-1-985160386910/jobs/pytorch-native-dist-2023-05-15-20-35-24-135/output/model.tar.gz'

# %%
import sagemaker
from sagemaker.pytorch import PyTorchModel

model = PyTorchModel(
    model_data=estimator.model_data,
    source_dir="code",
    entry_point="inference.py",
    role=role,
    framework_version="1.6.0",
    py_version="py3",
)

predictor = model.deploy(initial_instance_count=1, instance_type="ml.c5.xlarge")
# Out:
# -----!

# %%
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt

classes = ("plane", "car", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck")

def test_data_loader():
    transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor(), 
                                                torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
    testset = torchvision.datasets.CIFAR10(root="cifar10-dataset", 
                                           train=False, 
                                           download=False, 
                                           transform=transform)                                            
    return torch.utils.data.DataLoader(testset, batch_size=4, shuffle=True, num_workers=2)

def show_img(img):
    """displays an image"""
    img = img / 2 + 0.5  # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

# %%
# get some test images
dataiter = iter(test_data_loader())
images, labels = dataiter.next()

# print images, labels, and predictions
show_img(torchvision.utils.make_grid(images))
print("GroundTruth: ", " ".join("%4s" % classes[labels[j]] for j in range(4)))
outputs = predictor.predict(images)
_, predicted = torch.max(torch.from_numpy(np.array(outputs)), 1)

print("Predicted:   ", " ".join("%4s" % classes[predicted[j]] for j in range(4)))
# Out:
# [2023-05-15 20:51:57.863 1-8-1-cpu-py36-ml-t3-medium-05a4a7868130c7575335c53b16c7:79 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-05-15 20:51:58.216 1-8-1-cpu-py36-ml-t3-medium-05a4a7868130c7575335c53b16c7:79 INFO profiler_config_parser.py:102] Unable to find config at /opt/ml/input/config/profilerconfig.json. Profiler is disabled.
# GroundTruth:   car deer horse deer
# Predicted:     car deer deer deer
